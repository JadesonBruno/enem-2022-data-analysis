# %%
# Importando bibliotecas necessárias
import pandas as pd

# %%
# Carregando o arquivo
df_enem_2022 = pd.read_csv('MICRODADOS_ENEM_2022.csv', delimiter=";", encoding='1252') # encoding=1252 (Windows-1252)

# %%
# Olhando a base
display(df_enem_2022)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210057943671    2022               14       M                2
# 1        210057516120    2022               14       M                2
# 2        210057280536    2022                5       F                1
# 3        210055724397    2022                6       M                1
# 4        210055097896    2022                4       M                0
# ...               ...     ...              ...     ...              ...
# 3476100  210056389903    2022                3       M                1
# 3476101  210057205644    2022               14       F                2
# 3476102  210056699189    2022                2       M                1
# 3476103  210056983033    2022                3       M                1
# 3476104  210056307777    2022                2       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
# Removendo colunas desnecessárias para a análise
df_enem_2022 = df_enem_2022.drop(['NU_ANO','CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC','CO_UF_ESC','SG_UF_ESC','TP_DEPENDENCIA_ADM_ESC','TP_SIT_FUNC_ESC','CO_PROVA_CN','CO_PROVA_CH','CO_PROVA_LC','CO_PROVA_MT','TX_RESPOSTAS_CN',
    'TX_RESPOSTAS_CH','TX_RESPOSTAS_LC','TX_RESPOSTAS_MT','TX_GABARITO_CN','TX_GABARITO_CH','TX_GABARITO_LC','TX_GABARITO_MT','NU_NOTA_COMP1','NU_NOTA_COMP2','NU_NOTA_COMP3',
    'NU_NOTA_COMP4','NU_NOTA_COMP5','Q001','Q002','Q003','Q004','Q005','Q007','Q008','Q009','Q010','Q011','Q012','Q013','Q014','Q015','Q016','Q017','Q018','Q019','Q020','Q021','Q022',
    'Q023','Q024','Q025'], axis=1)

# %%
# Olhando a base depois da remoção das colunas
display(df_enem_2022)
# Out:
#          NU_INSCRICAO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0        210057943671               14       M                2            2
# 1        210057516120               14       M                2            1
# 2        210057280536                5       F                1            2
# 3        210055724397                6       M                1            3
# 4        210055097896                4       M                0            3
# ...               ...              ...     ...              ...          ...
# 3476100  210056389903                3       M                1            1
# 3476101  210057205644               14       F                2            1
# 3476102  210056699189                2       M                1            1
# 3476103  210056983033                3       M                1            3
# 3476104  210056307777                2       F                2            3
#
# ...

# %%
# Exportando o dataframe para CSV
df_enem_2022.to_csv('dataset_enem_2022.csv', index=False, sep=';', encoding='utf-8')

# %%
# Filtrando o Dataframe em uma amostra de 100.000 instâncias
df_enem_2022_filtrado = df_enem_2022.sample(n=100000, random_state=1)

# %%
# Vizualizando o Dataframe filtrado
display(df_enem_2022_filtrado)
# Out:
#          NU_INSCRICAO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 644985   210056500144                2       M                1            1
# 443117   210055400403                3       M                1            1
# 1005929  210056000036                6       F                1            3
# 384479   210056383245                2       M                0            0
# 261434   210057669224                2       M                1            2
# ...               ...              ...     ...              ...          ...
# 2402101  210056184821                2       M                3            1
# 1352288  210055270573                5       F                0            3
# 3042671  210056376332               14       F                2            3
# 2740327  210056259560                3       M                1            3
# 1025708  210058000189                2       F                1            3
#
# ...

# %%
# Exportando o Dataframe filtrado para o formato CSV
df_enem_2022_filtrado.to_csv('dataset_enem_2022_filtrado.csv', index=False, sep=';', encoding='utf-8')
